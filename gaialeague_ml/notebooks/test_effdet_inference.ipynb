# %%
import sys,os
sys.path.insert(0, "..")

# %%
from matplotlib import pyplot as plt

# %%
import cv2

# %%
from detector.effdet import make_predictions, rectangle, imread

# %%
predictions, images = make_predictions(["../datasets/wild-test-data/canada-day-litter.jpg"]*2, wbf=True)
len(predictions)
# Out:
# 2

# %%
from  tempfile import TemporaryFile, NamedTemporaryFile

# %%
with NamedTemporaryFile(suffix=".png") as f:
    print(f.name)
    with NamedTemporaryFile() as f2:
        print("f2:", f2.name)
# Out:
# C:\Users\NKA\AppData\Local\Temp\tmp3hqt567z.png
# f2: C:\Users\NKA\AppData\Local\Temp\tmp83isul6w

# %%
with open("../image_after.png", "rb") as f1:
    with open("../image_after.png", "rb") as f2:
        f2.read()

# %%
predictions
# Out:
# [{'boxes': array([[240, 100, 368, 161],
#          [162, 237, 245, 281],
#          [524, 263, 568, 299],
#          [232, 352, 292, 393]]),
#   'scores': array([0.65870881, 0.57470155, 0.54129493, 0.49291489])},
#  {'boxes': array([[240, 100, 368, 161],
#          [162, 237, 245, 281],
#          [524, 263, 568, 299],
#          [232, 352, 292, 393]]),
#   'scores': array([0.65870881, 0.57470155, 0.54129493, 0.49291489])}]

# %%
import cv2,os
from pathlib import Path

# %%
# cv2.imread()

# %%
filepath = '/some/path/to/local/file.txt'
os.path.basename(filepath), os.path.dirname(filepath)
# Out:
# ('file.txt', '/some/path/to/local')

# %%
"{:.06f}".format(1.1)
# Out:
# '1.100000'

# %%
image, box = images[0], predictions[0]["boxes"][0]
box
# Out:
# array([240, 100, 368, 161])

# %%
rectangle(image, box)
print()

# %%
fig,ax = plt.subplots(1, 1,figsize=(30, 10))
ax.imshow(image)

# %%
# fig,ax = plt.subplots(1, 1,figsize=(30, 10))
# ax.imshow(image)

# %%
# list(zip(*[(1,2,3), (1,2,3)]))
