# %%
import sys,os
sys.path.insert(0, "..")

# %%
from matplotlib import pyplot as plt

# %%
import cv2

# %%
from detector.effdet import make_predictions, rectangle, imread

# %%
predictions = make_predictions(["../datasets/wild-test-data/canada-day-litter.jpg"], wbf=True)[0]
image = predictions["image"]
len(predictions)
# Out:
# C:\Users\NKA\Anaconda3\lib\site-packages\ensemble_boxes\ensemble_boxes_wbf.py:76: UserWarning: Y1 < 0 in box. Set it to 0.
#   warnings.warn('Y1 < 0 in box. Set it to 0.')
# 3

# %%
predictions
# Out:
# {'boxes': array([[362, 215, 426, 283],
#         [350, 294, 502, 372],
#         [232, 101, 368, 161],
#         [232, 351, 295, 394],
#         [155, 236, 245, 283],
#         [507,   0, 559,  82]]),
#  'scores': array([0.53674859, 0.44685453, 0.43810576, 0.39443669, 0.29812381,
#         0.25694406]),
#  'image': array([[[0.11372549, 0.12941177, 0.14117648],
#          [0.11372549, 0.12941177, 0.14117648],
#          [0.10588235, 0.12156863, 0.13333334],
#          ...,
#          [0.28627452, 0.34509805, 0.22352941],
#          [0.28235295, 0.34117648, 0.21960784],
#          [0.2627451 , 0.32156864, 0.2       ]],
#
#         [[0.11372549, 0.12941177, 0.14117648],
#          [0.10980392, 0.1254902 , 0.13725491],
#          [0.10588235, 0.12156863, 0.13333334],
#          ...,
#          [0.27058825, 0.32941177, 0.20784314],
#          [0.28627452, 0.34509805, 0.22352941],
#          [0.30980393, 0.36862746, 0.24705882]],
#
#         [[0.11372549, 0.12941177, 0.14117648],
# ...

# %%
box = predictions["boxes"][0]
box
# Out:
# array([362, 215, 426, 283])

# %%
fig,ax = plt.subplots(1, 1,figsize=(30, 10))
ax.imshow(image)
